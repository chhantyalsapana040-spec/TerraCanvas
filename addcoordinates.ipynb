# %% [markdown]
# # Generate Latitude and Longitude for Cities

# %%
# !pip install geopy pandas
# Out:
# Requirement already satisfied: geopy in c:\users\legio\.conda\envs\nlp\lib\site-packages (2.4.1)
# Requirement already satisfied: pandas in c:\users\legio\.conda\envs\nlp\lib\site-packages (2.3.3)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\legio\.conda\envs\nlp\lib\site-packages (from geopy) (2.1)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\legio\.conda\envs\nlp\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\legio\.conda\envs\nlp\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\legio\.conda\envs\nlp\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\legio\.conda\envs\nlp\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\legio\.conda\envs\nlp\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# WARNING: Error parsing dependencies of datasets: [Errno 2] No such file or directory: 'c:\\users\\legio\\.conda\\envs\\nlp\\lib\\site-packages\\datasets-4.4.2.dist-info\\METADATA'
# WARNING: Error parsing dependencies of dill: [Errno 2] No such file or directory: 'c:\\users\\legio\\.conda\\envs\\nlp\\lib\\site-packages\\dill-0.4.0.dist-info\\METADATA'
# WARNING: Error parsing dependencies of evaluate: [Errno 2] No such file or directory: 'c:\\users\\legio\\.conda\\envs\\nlp\\lib\\site-packages\\evaluate-0.4.6.dist-info\\METADATA'

# %%
import pandas as pd
from geopy.geocoders import Nominatim
import time

# %%
# Load the CSV dataset
df = pd.read_csv("environment_data.csv")
df.head()
# Out:
#          Date         City Country  AQI  PM2.5 (µg/m³)  PM10 (µg/m³)  \
# 0  2024-01-01     New York     USA   38          120.0         182.9
# 1  2024-01-01  Los Angeles     USA  280           38.4          46.9
# 2  2024-01-01       London      UK  117          168.1          34.3
# 3  2024-01-01      Beijing   China  197           96.8          35.4
# 4  2024-01-01        Delhi   India  187           76.2         226.8
#
#    NO2 (ppb)  SO2 (ppb)  CO (ppm)  O3 (ppb)  Temperature (°C)  Humidity (%)  \
# 0       24.3       26.0      9.10     153.3              18.6            40
# 1       41.8       34.7      3.78     190.7              -2.2            59
# 2       81.5        8.2      3.67     105.4              36.3            62
# 3       18.5       39.4      9.51      92.8              29.9            32
# 4       46.9       17.2      1.02      68.4               9.9            55
#
#    Wind Speed (m/s)
# 0              13.2
# 1               9.5
# 2               3.4
# 3               1.8
# 4               3.3

# %%
geolocator = Nominatim(user_agent="terracanvas_ipynb")

# %%
def get_lat_lon(city, country):
    """
    Returns latitude and longitude for a given city and country.
    If location is not found, returns (None, None).
    """
    try:
        location = geolocator.geocode(f"{city}, {country}")
        if location:
            return location.latitude, location.longitude
    except:
        pass
    return None, None

# %%
# Get unique city-country pairs
unique_cities = df[['City', 'Country']].drop_duplicates().reset_index(drop=True)

# Lists to store coordinates
latitudes = []
longitudes = []

# Geocode each unique city
for i, row in unique_cities.iterrows():
    city = row['City']
    country = row['Country']
    lat, lon = get_lat_lon(city, country)
    latitudes.append(lat if lat else 0)
    longitudes.append(lon if lon else 0)
    print(f"{i+1}/{len(unique_cities)}: {city}, {country} => lat: {lat}, lon: {lon}")
    time.sleep(1)  # pause to avoid API limits

# Add coordinates to unique_cities DataFrame
unique_cities['Latitude'] = latitudes
unique_cities['Longitude'] = longitudes
# Out:
# 1/10: New York, USA => lat: 40.7127281, lon: -74.0060152
# 2/10: Los Angeles, USA => lat: 34.0536909, lon: -118.242766
# 3/10: London, UK => lat: 51.5074456, lon: -0.1277653
# 4/10: Beijing, China => lat: 40.190632, lon: 116.412144
# 5/10: Delhi, India => lat: 28.6138954, lon: 77.2090057
# 6/10: Paris, France => lat: 48.8588897, lon: 2.320041
# 7/10: Tokyo, Japan => lat: 35.6768601, lon: 139.7638947
# 8/10: Sydney, Australia => lat: -33.8698439, lon: 151.2082848
# 9/10: São Paulo, Brazil => lat: -23.5506507, lon: -46.6333824
# 10/10: Cairo, Egypt => lat: 30.0443879, lon: 31.2357257

# %%
# Merge coordinates back to original dataset
df = df.merge(unique_cities, on=['City', 'Country'], how='left')
df.head()
# Out:
#          Date         City Country  AQI  PM2.5 (µg/m³)  PM10 (µg/m³)  \
# 0  2024-01-01     New York     USA   38          120.0         182.9
# 1  2024-01-01  Los Angeles     USA  280           38.4          46.9
# 2  2024-01-01       London      UK  117          168.1          34.3
# 3  2024-01-01      Beijing   China  197           96.8          35.4
# 4  2024-01-01        Delhi   India  187           76.2         226.8
#
#    NO2 (ppb)  SO2 (ppb)  CO (ppm)  O3 (ppb)  Temperature (°C)  Humidity (%)  \
# 0       24.3       26.0      9.10     153.3              18.6            40
# 1       41.8       34.7      3.78     190.7              -2.2            59
# 2       81.5        8.2      3.67     105.4              36.3            62
# 3       18.5       39.4      9.51      92.8              29.9            32
# 4       46.9       17.2      1.02      68.4               9.9            55
#
#    Wind Speed (m/s)   Latitude   Longitude
# 0              13.2  40.712728  -74.006015
# 1               9.5  34.053691 -118.242766
# 2               3.4  51.507446   -0.127765
# 3               1.8  40.190632  116.412144
# 4               3.3  28.613895   77.209006

# %%
# Save updated dataset with coordinates
df.to_csv("environment_data_with_coords.csv", index=False)
print("Updated CSV saved as 'environment_data_with_coords.csv'")
# Out:
# Updated CSV saved as 'environment_data_with_coords.csv'
